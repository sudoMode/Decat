# %%
import pandas as pd

# %%
p1 = '/Users/mandeepsingh/dev/projects/py/Decat/raw_vocab/unigrams_by_frequency.csv'
p2 = '/Users/mandeepsingh/dev/projects/py/Decat/decat/data/vocabulary/words-by-frequency.txt'

# %%
d1 = pd.read_csv(p1)
# d2 = pd.read_csv(p2, header=None)

# %%
d1.head()
# Out:
#   word        count
# 0  the  23135851162
# 1   of  13151942776
# 2  and  12997637966
# 3   to  12136980858
# 4    a   9081174698

# %%
d2.head()
# Out:
#      0
# 0  the
# 1   of
# 2   in
# 3    a
# 4  and

# %%
d1.shape, d2.shape
# Out:
# ((333333, 2), (125549, 1))

# %%
d1.shape[0] / d2.shape[0]
# Out:
# 2.655003225832145

# %%
l1 = d1.word.values.tolist()
l2 = d1.word.unique().tolist()

# %%
len(l1), len(l2)
# Out:
# (333333, 333332)

# %%
set(l2).difference(l1)
# Out:
# set()

# %%
d1.word.values.tolist()
# Out:
# ['the',
#  'of',
#  'and',
#  'to',
#  'a',
#  'in',
#  'for',
#  'is',
#  'on',
#  'that',
#  'by',
#  'this',
#  'with',
#  'i',
#  'you',
#  'it',
#  'not',
#  'or',
#  'be',
#  'are',
#  'from',
#  'at',
#  'as',
#  'your',
#  'all',
#  'have',
#  'new',
#  'more',
#  'an',
#  'was',
#  'we',
#  'will',
#  'home',
#  'can',
#  'us',
#  'about',
#  'if',
#  'page',
#  'my',
#  'has',
#  'search',
#  'free',
#  'but',
#  'our',
#  'one',
#  'other',
#  'do',
#  'no',
#  'information',
#  'time',
#  'they',
#  'site',
#  'he',
#  'up',
#  'may',
#  'what',
#  'which',
#  'their',
#  'news',
#  'out',
#  'use',
#  'any',
#  'there',
#  'see',
#  'only',
#  'so',
#  'his',
#  'when',
#  'contact',
#  'here',
#  'business',
#  'who',
#  'web',
#  'also',
#  'now',
#  'help',
#  'get',
#  'pm',
#  'view',
#  'online',
#  'c',
#  'e',
#  'first',
#  'am',
#  'been',
#  'would',
#  'how',
#  'were',
#  'me',
#  's',
#  'services',
#  'some',
#  'these',
#  'click',
#  'its',
#  'like',
# ...

# %%
d1[:100]
# Out:
#        word        count
# 0       the  23135851162
# 1        of  13151942776
# 2       and  12997637966
# 3        to  12136980858
# 4         a   9081174698
# ..      ...          ...
# 95     like    520585287
# 96  service    519537222
# 97        x    508609523
# 98     than    502609275
# 99     find    502043038
#
# [100 rows x 2 columns]

# %%
d2[:100]
# Out:
#             0
# 0         the
# 1          of
# 2          in
# 3           a
# 4         and
# ..        ...
# 95       over
# 96  different
# 97        out
# 98        use
# 99     france
#
# [100 rows x 1 columns]

# %%
d1[d1.word == 'iam']
# Out:
#       word    count
# 25755  iam  1037240

# %%
d2[~d2[0].isin(d1.word)][:50]
# Out:
#                    0
# 894        partement
# 1106          ifexpr
# 3999       sanfrecce
# 4117     pakhtunkhwa
# 4229            aang
# 4780          avispa
# 4823          vissel
# 4864       wikitable
# 4893       noinclude
# 4911        bellmare
# 5088       consadole
# 5089            xona
# 5205            tosu
# 5266       rttemberg
# 5410         vegalta
# 5476          reysol
# 5554         albirex
# 5941          ffffff
# 5950        frontale
# 6342       checkuser
# 6357       ventforet
# 6360            dolj
# 6458          beyonc
# 6507          ardija
# 6618         leonese
# 6629        barnstar
# 6687        montedio
# 7002          vortis
# 7489         yotcmdr
# 7771            gwib
# 7989            enwp
# 8190          thespa
# 8325            prva
# 8384    nationalliga
# 8492         tehsils
# 8622         balukas
# 8818          katara
# 8870            ozai
# 8883       mainspace
# 8906         chakwal
# 9434            hler
# 9460   nchengladbach
# ...

# %%
d1.iloc[1100:1110]
# Out:
#            word     count
# 1100        usr  73064522
# 1101  executive  73010727
# 1102    running  72879426
# 1103      lower  72606927
# 1104  necessary  72604405
# 1105      union  72603888
# 1106    jewelry  72576719
# 1107  according  72553085
# 1108         dc  72528782
# 1109   clothing  72455943

# %%
d1[d1.word == 'iam']
# Out:
#       word    count
# 25755  iam  1037240

# %%
d2[d2[0] == 'iam']
# Out:
#          0
# 49229  iam

# %%
import sys

# %%
a = ','.join(map(str, d1.word.tolist()))

# %%
sys.getsizeof(a) / 1024 / 1024
# Out:
# 2.6926889419555664

# %%
import json

# %%
with open('vocabulary.json', 'w') as f:
    f.write(json.dumps(d1['word'].tolist(), indent=1))

# %%
d1.to_csv('temp3.csv', index=False)

# %%
d1
# Out:
#            word        count
# 0           the  23135851162
# 1            of  13151942776
# 2           and  12997637966
# 3            to  12136980858
# 4             a   9081174698
# ...         ...          ...
# 333328    gooek        12711
# 333329   gooddg        12711
# 333330  gooblle        12711
# 333331   gollgo        12711
# 333332    golgw        12711
#
# [333333 rows x 2 columns]

# %%
v = d1.word.tolist()
for i in range(len(v)):
    v1 = v[i]
    t = type(v1)
    if t != str:
        print(f'S: {v1} | T: {t} | I: {i}')
# Out:
# S: nan | T: <class 'float'> | I: 2577
# S: nan | T: <class 'float'> | I: 12819

# %%
d1.shape
# Out:
# (333333, 2)

# %%
d1.dropna(inplace=True)

# %%
d1.shape
# Out:
# (333331, 2)

# %%
import re

# %%
s = ' jus:_t a te--ststri+^#ng 123 @)(&)(&) ando{}:>?ne mor\09e_of this @# is here '

# %%
re.sub('\W+','', s)
# Out:
# 'jus_tateststring123andonemor9e_ofthisishere'

# %%
''.join(e for e in s if e.isalpha())
# Out:
# 'justateststringandonemoreofthisishere'
